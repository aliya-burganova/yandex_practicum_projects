# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта:" data-toc-modified-id="Описание-проекта:-1">Описание проекта:</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2">Описание данных</a></span></li><li><span><a href="#Шаг-1.-Подготовка-данных" data-toc-modified-id="Шаг-1.-Подготовка-данных-3">Шаг 1. Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1">Вывод</a></span></li></ul></li><li><span><a href="#Шаг-2.-Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Шаг-2.-Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-4">Шаг 2. Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Расчет" data-toc-modified-id="Расчет-4.1">Расчет</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-4.1.1">Профили пользователей</a></span></li><li><span><a href="#Удержание" data-toc-modified-id="Удержание-4.1.2">Удержание</a></span></li><li><span><a href="#Конверсия" data-toc-modified-id="Конверсия-4.1.3">Конверсия</a></span></li><li><span><a href="#LTV-+-ROI" data-toc-modified-id="LTV-+-ROI-4.1.4">LTV + ROI</a></span></li></ul></li><li><span><a href="#Сглаживание-фрейма" data-toc-modified-id="Сглаживание-фрейма-4.2">Сглаживание фрейма</a></span></li><li><span><a href="#Визуализации" data-toc-modified-id="Визуализации-4.3">Визуализации</a></span><ul class="toc-item"><li><span><a href="#Удержание" data-toc-modified-id="Удержание-4.3.1">Удержание</a></span></li><li><span><a href="#Конверсия" data-toc-modified-id="Конверсия-4.3.2">Конверсия</a></span></li><li><span><a href="#LTV-+-ROI" data-toc-modified-id="LTV-+-ROI-4.3.3">LTV + ROI</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-5">Шаг 3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1">Вывод</a></span></li></ul></li><li><span><a href="#Шаг-4.-Маркетинг" data-toc-modified-id="Шаг-4.-Маркетинг-6">Шаг 4. Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.1">Вывод</a></span></li></ul></li><li><span><a href="#Шаг-5.-Окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Шаг-5.-Окупаемость-рекламы-для-привлечения-пользователей-7">Шаг 5. Окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-7.1">Общая окупаемость рекламы</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-7.2">Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-7.3">Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-7.4">Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.5">Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-8">Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта:

# %% [markdown]
# Разобраться в причинах убыточности привлечения пользователей развлекательного приложения Procrastinate Pro+
#
# У нас в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
#
# Мы смотрим данные 1-го ноября 2019 года и в организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ## Описание данных
#
# Таблица **visits_log_short** (лог сервера с информацией о посещениях сайта):
#
# - `User Id` — уникальный идентификатор пользователя
# - `Device` — категория устройства пользователя
# - `Session start` — дата и время начала сессии
# - `Session End` — дата и время окончания сессии
# - `Channel` — идентификатор рекламного источника, из которого пришел пользователь
# - `Region` - страна пользователя
#
# Таблица **orders_log_short** (информация о заказах):
#
# - `User Id` — уникальный id пользователя, который сделал заказ
# - `Event Dt` — дата и время покупки
# - `Revenue` — выручка
#
# Таблица **costs_short** (информация о затратах на маркетинг):
#
# - `Channel` — идентификатор рекламного источника
# - `Dt` — дата
# - `Costs` — затраты на этот рекламный источник в этот день

# %% [markdown]
# ## Шаг 1. Подготовка данных

# %%
import pandas as pd
from datetime import timedelta
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.float_format', '{:.2f}'.format)

# %%
class text_colors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %%
def review(table, table_name):
    '''
    Функция печатает на экран общую информацию о таблице,
    первые 5 строк таблицы, число пропусков в каждом столбце,
    число дубликатов, описательную статистику
    
    '''
    print(text_colors.OKGREEN + text_colors.BOLD 
          + f'Предварительный анализ таблицы {table_name}' 
          + text_colors.ENDC
          + text_colors.ENDC
         )
    print()
    print(text_colors.BOLD + 'Общая информация о таблице:' + text_colors.ENDC)
    table.info()
    print()
    print()
    
    print(text_colors.BOLD + 'Первые 5 строк таблицы:' + text_colors.ENDC)
    display(table.head())
    print()
    print()
    
    print(text_colors.BOLD + 'Число пропусков в каждом столбце:' + text_colors.ENDC)
    
    nans = pd.DataFrame(table.isna().sum()).rename(columns={0:'abs'})
    nans['rel %'] = nans['abs'].apply(lambda x: round(x/table.shape[0], 1))
    display(nans.style.format({'rel %' : '{:.1%}'}))
    
    print()
    print()
    
    print(text_colors.BOLD 
          + f'Число дубликатов в таблице: {table.duplicated().sum()}' 
          + text_colors.ENDC)
    print()
    print()
    print(text_colors.BOLD + 'Описательная статистика:' + text_colors.ENDC)
    display(table.describe().T)

# %%
def rename_columns(table):
    
    new_columns = []
    for col in table.columns:
        col_split = col.split(' ')
        new_columns.append('_'.join([x for x in col_split if x != '']).lower())
    table.columns = new_columns

# %% [markdown]
# ***

# %%
visits = pd.read_csv('visits_info_short.csv')
orders = pd.read_csv('orders_info_short.csv')
costs = pd.read_csv('costs_info_short.csv')

# %% [markdown]
# Приведем столбцы к нижнему регистру.

# %%
for table in [visits, orders, costs]:
    rename_columns(table)

# %% [markdown]
# Изучим общую информацию о данных.

# %%
review(visits, 'visits')
# Out:
# Предварительный анализ таблицы visits
#
# Общая информация о таблице:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   unnamed:_0     309901 non-null  int64
#  1   user_id        309901 non-null  int64
#  2   region         309901 non-null  object
#  3   device         309901 non-null  object
#  4   channel        309901 non-null  object
#  5   session_start  309901 non-null  object
#  6   session_end    309901 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 16.6+ MB
#
#
# Первые 5 строк таблицы:
#    unnamed:_0       user_id         region   device  channel  \
# 0           0  981449118918  United States   iPhone  organic
# 1           1  278965908054  United States   iPhone  organic
# 2           2  590706206550  United States      Mac  organic
# ...

# %% [markdown]
# ***

# %%
review(orders, 'orders')
# Out:
# Предварительный анализ таблицы orders
#
# Общая информация о таблице:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unnamed:_0  40212 non-null  int64
#  1   user_id     40212 non-null  int64
#  2   event_dt    40212 non-null  object
#  3   revenue     40212 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.2+ MB
#
#
# Первые 5 строк таблицы:
#    unnamed:_0       user_id             event_dt  revenue
# 0           0  188246423999  2019-05-01 23:09:52     4.99
# 1           1  174361394180  2019-05-01 12:24:04     4.99
# 2           2  529610067795  2019-05-01 11:34:04     4.99
# 3           3  319939546352  2019-05-01 15:34:40     4.99
# 4           4  366000285810  2019-05-01 13:59:51     4.99
# Число пропусков в каждом столбце:
# <style  type="text/css" >
# ...

# %% [markdown]
# ***

# %%
review(costs, 'costs')
# Out:
# Предварительный анализ таблицы costs
#
# Общая информация о таблице:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unnamed:_0  1800 non-null   int64
#  1   dt          1800 non-null   object
#  2   channel     1800 non-null   object
#  3   costs       1800 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 56.4+ KB
#
#
# Первые 5 строк таблицы:
#    unnamed:_0          dt   channel  costs
# 0           0  2019-05-01  FaceBoom 113.30
# 1           1  2019-05-02  FaceBoom  78.10
# 2           2  2019-05-03  FaceBoom  85.80
# 3           3  2019-05-04  FaceBoom 136.40
# 4           4  2019-05-05  FaceBoom 122.10
# Число пропусков в каждом столбце:
# <style  type="text/css" >
# ...

# %% [markdown]
# Приведем все даты к нужному формату.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Пропусков в данных нет.
# - Дубликатов в таблицах нет.
# - Столбцы приведены к нижнему регистру.
# - Даты приведены к нужному формату.

# %% [markdown]
# ## Шаг 2. Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Расчет

# %% [markdown]
# #### Профили пользователей

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# #### Удержание

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions #

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Конверсия

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### LTV + ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Сглаживание фрейма

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Визуализации

# %% [markdown]
# #### Удержание

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Конверсия

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### LTV + ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Построим профили пользователей. Определим минимальную и максимальную дату привлечения пользователей.
#
# Выясним:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %%
profiles = get_profiles(visits, orders, costs)

# %%
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True              1.09
# 1  2019-07-09 2019-07-01  False              1.11
# 2  2019-10-01 2019-10-01  False              0.00
# 3  2019-08-22 2019-08-01  False              0.99
# 4  2019-10-02 2019-10-01  False              0.23

# %%
min_date = profiles['first_ts'].min()
max_date = profiles['first_ts'].max()

# %%
print('Минимальная дата привлечения:', min_date.date())
print('Максимальная дата привлечения:', max_date.date())
# Out:
# Минимальная дата привлечения: 2019-05-01
# Максимальная дата привлечения: 2019-10-27

# %% [markdown]
# У нас имеются данные о пользователях за полгода - с мая по октябрь 2019 года.

# %% [markdown]
# Определим какие страны приносят больше всего платящих пользователей.

# %%
def group_profiles(profiles, group_by, sort_by):
    payers = (
        profiles
        .groupby(group_by)
        .agg({'user_id':'nunique', 'payer':['sum', 'mean']})
    )
    
    payers.columns = ['users', 'payers', 'payers_ratio']
    payers = payers.sort_values(by=sort_by, ascending=False).style.format({'payers_ratio':'{:.2%}'})
    return payers

# %%
group_profiles(profiles, 'region', 'users')
# Out:
# <style  type="text/css" >
# </style><table id="T_36f2b4e2_d42a_11ec_a3bc_bce92ff98047" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >payers</th>        <th class="col_heading level0 col2" >payers_ratio</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36f2b4e2_d42a_11ec_a3bc_bce92ff98047level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_36f2b4e2_d42a_11ec_a3bc_bce92ff98047row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_36f2b4e2_d42a_11ec_a3bc_bce92ff98047row0_col1" class="data row0 col1" >6902</td>
# ...

# %% [markdown]
# - Больше всего пользователей привлечено из США - в 5-6 раз больше чем из других стран.
# - Так же и процент платящих пользователей самый высокий - 6.9%.

# %% [markdown]
# Определим с каких устройств чаще заходят платящие пользователи

# %%
group_profiles(profiles, 'device', 'users')
# Out:
# <style  type="text/css" >
# </style><table id="T_36fcfc09_d42a_11ec_bc10_bce92ff98047" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >payers</th>        <th class="col_heading level0 col2" >payers_ratio</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36fcfc09_d42a_11ec_bc10_bce92ff98047level0_row0" class="row_heading level0 row0" >iPhone</th>
#                         <td id="T_36fcfc09_d42a_11ec_bc10_bce92ff98047row0_col0" class="data row0 col0" >54479</td>
#                         <td id="T_36fcfc09_d42a_11ec_bc10_bce92ff98047row0_col1" class="data row0 col1" >3382</td>
# ...

# %% [markdown]
# - Больше всего пользователей и платящих пользователей заходят в приложение с iPhone.
# - Самый высокий процент платящих пользователей у Mac.

# %% [markdown]
# Разделим пользователей по региону - США и Европа и посмотрим с каких девайсов заходят пользователи по регионам.

# %%
profiles['region_type'] = np.where(profiles['region'] == 'United States', 'USA', 'EU')

# %%
group_profiles(profiles, ['region_type', 'device'], ['region_type','users'])
# Out:
# <style  type="text/css" >
# </style><table id="T_37121921_d42a_11ec_8025_bce92ff98047" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >payers</th>        <th class="col_heading level0 col2" >payers_ratio</th>    </tr>    <tr>        <th class="index_name level0" >region_type</th>        <th class="index_name level1" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37121921_d42a_11ec_8025_bce92ff98047level0_row0" class="row_heading level0 row0" rowspan=4>USA</th>
#                         <th id="T_37121921_d42a_11ec_8025_bce92ff98047level1_row0" class="row_heading level1 row0" >iPhone</th>
#                         <td id="T_37121921_d42a_11ec_8025_bce92ff98047row0_col0" class="data row0 col0" >44529</td>
# ...

# %% [markdown]
# - В США пользователи чаще всего используют iPhone и Mac
# - В Епропе - PC и Android

# %% [markdown]
# Определим с каких каналов чаще привлекаются платящие пользователи

# %%
group_profiles(profiles, 'channel', 'users')
# Out:
# <style  type="text/css" >
# </style><table id="T_371eef3c_d42a_11ec_9eaa_bce92ff98047" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >payers</th>        <th class="col_heading level0 col2" >payers_ratio</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_371eef3c_d42a_11ec_9eaa_bce92ff98047level0_row0" class="row_heading level0 row0" >organic</th>
#                         <td id="T_371eef3c_d42a_11ec_9eaa_bce92ff98047row0_col0" class="data row0 col0" >56439</td>
#                         <td id="T_371eef3c_d42a_11ec_9eaa_bce92ff98047row0_col1" class="data row0 col1" >1160</td>
# ...

# %% [markdown]
# - Больше всего пользователей и платящих пользователей приносят FaceBoom и TipTop, так же у них высокие проценты платящих пользователей
# - По проценту платящих пользователей так же выделяются AdNonSense и lambdaMediaAds. Стоит обратить на них внимание.

# %% [markdown]
# Посмотрим с каких каналов приходят пользователи по регионам.

# %%
group_profiles(profiles, ['region_type', 'channel'], ['region_type', 'users'])
# Out:
# <style  type="text/css" >
# </style><table id="T_372e3422_d42a_11ec_b20a_bce92ff98047" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >payers</th>        <th class="col_heading level0 col2" >payers_ratio</th>    </tr>    <tr>        <th class="index_name level0" >region_type</th>        <th class="index_name level1" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_372e3422_d42a_11ec_b20a_bce92ff98047level0_row0" class="row_heading level0 row0" rowspan=6>USA</th>
#                         <th id="T_372e3422_d42a_11ec_b20a_bce92ff98047level1_row0" class="row_heading level1 row0" >organic</th>
# ...

# %% [markdown]
# В США и Европе используются разные каналы привлечения пользователей.
# - В США популярны FaceBoom и TipTop они же и приносят самое большое число покупателей
# - В Европе же наиболее популярные каналы привлечения приносят очень малое число покупателей.

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Самое большое число платящих пользователей приходится на США, число привлеченных пользователей в 5-6 раз превышает числа пользователей из стран Европы.
# - В общем:
#     - Больше всего пользователей и платящих пользователей заходят в приложение с iPhone.
#     - Самый высокий процент платящих пользователей у Mac.
#
#   В разбивке по регионам:
#     - В США больше пользователи чаще всего используют iPhone и Mac
#     - В Епропе - PC и Android
#
# - Больше всего пользователей и платящих пользователей приносят FaceBoom и TipTop, так же у них высокие проценты платящих пользователей
# - По проценту платящих пользователей так же выделяются AdNonSense и lambdaMediaAds. Стоит обратить на них внимание.

# %% [markdown]
# ## Шаг 4. Маркетинг

# %% [markdown]
# Выясним:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %%
observation_date = pd.to_datetime('2019-11-01')
observation_date
analysis_horizon = 14
last_suitable_acquisition_date = observation_date - timedelta(days=analysis_horizon - 1)

# %%
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost region_type
# 0  2019-05-07 2019-05-01   True              1.09         USA
# 1  2019-07-09 2019-07-01  False              1.11         USA
# 2  2019-10-01 2019-10-01  False              0.00          EU
# 3  2019-08-22 2019-08-01  False              0.99          EU
# 4  2019-10-02 2019-10-01  False              0.23         USA

# %%
print(
    'Всего на привлечение пользователей было потрачено:', 
    round(profiles['acquisition_cost'].sum()), 
    'у.е.'
)
# Out:
# Всего на привлечение пользователей было потрачено: 105497 у.е.

# %% [markdown]
# Посмотрим, сколько денег было вложены в различные каналы привлечения.

# %%
channel_acquisition = (
    profiles.query('channel!="organic"')
    .groupby('channel')
    .agg({'acquisition_cost':'sum'})
)

channel_acquisition.columns = ['acq_sum']
channel_acquisition['acq_sum_ratio'] = (
    channel_acquisition['acq_sum']
    .apply(lambda x: str(round(x/profiles['acquisition_cost'].sum()*100, 2)) + '%')
)
channel_acquisition.sort_values(by='acq_sum', ascending=False)
# Out:
#                     acq_sum acq_sum_ratio
# channel
# TipTop             54751.30         51.9%
# FaceBoom           32445.60        30.75%
# WahooNetBanner      5151.00         4.88%
# AdNonSense          3911.25         3.71%
# OppleCreativeMedia  2151.25         2.04%
# RocketSuperAds      1833.00         1.74%
# LeapBob             1797.60          1.7%
# lambdaMediaAds      1557.60         1.48%
# MediaTornado         954.48          0.9%
# YRabbit              944.22          0.9%

# %% [markdown]
# Больше всего денег было вложено в привлечение пользователей с FaceBoom (30.75%) и TipTop (51.9%)

# %% [markdown]
# Построим график затрат по времени, сгладим график с шириной окна 7.

# %%
(
    filter_data(
        profiles
        .pivot_table(index='dt',values='acquisition_cost', aggfunc='sum'),
        window=7)
    .plot(grid=True, figsize=(15, 6))
)
plt.legend()
plt.title("Затраты на привлечение пользователей по времени")
plt.xlabel('Дата привлечения')
plt.ylabel('Стоимость привлечения');

# %% [markdown]
# Общая тенденция на увеличение расходов на привлечение пользователей.
#
# На начало каждого месяца приходится скачок в увеличении затрат, к середине месяца затраты снижаются.

# %% [markdown]
# ***

# %% [markdown]
# Рассчитаем среднюю стоимость привлечения пользователей в общем и в разбивке по каналам.

# %%
print('Средняя стоимость привлечения пользователя (без органических пользователей):',
      round(profiles.query('channel!="organic"')['acquisition_cost'].mean(), 2), 'у.е.'
     )
# Out:
# Средняя стоимость привлечения пользователя (без органических пользователей): 1.13 у.е.

# %% [markdown]
# Посмотрим на затраты на привлечение одного пользователя по разным каналам.

# %%
(
    profiles
    .groupby('channel')
    .agg({'acquisition_cost':'mean'})
    .sort_values(by ='acquisition_cost', ascending=False)
)
# Out:
#                     acquisition_cost
# channel
# TipTop                          2.80
# FaceBoom                        1.11
# AdNonSense                      1.01
# lambdaMediaAds                  0.72
# WahooNetBanner                  0.60
# RocketSuperAds                  0.41
# OppleCreativeMedia              0.25
# YRabbit                         0.22
# MediaTornado                    0.22
# LeapBob                         0.21
# organic                         0.00

# %% [markdown]
# Ожидаемо самые высокие цены на привлечение одного пользователя приходятся на `FaceBoom` и `TipTop`, за ними следом идут `AdNonSense` и `lambdaMediaAds` - лидеры в Европе по конверсии.

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Всего на привлечение пользователей было потрачено: 105497 у.е.
# - Больше всего денег было вложено в привлечение пользователей с FaceBoom (30.75%) и TipTop (51.9%)
# - Общая тенденция на увеличение расходов на привлечение пользователей. На начало каждого месяца приходится скачок в увеличении затрат, к середине месяца затраты снижаются.
# - Средняя стоимость привлечения пользователя (без органических пользователей): 1.13 у.е.
# - Самые высокие цены на привлечение одного пользователя приходятся на `FaceBoom` и `TipTop`, за ними следом идут `AdNonSense` и `lambdaMediaAds` - лидеры в Европе по конверсии.

# %% [markdown]
# ## Шаг 5. Окупаемость рекламы для привлечения пользователей

# %% [markdown]
# С помощью LTV и ROI:
# - Проанализируем общую окупаемость рекламы;
# - Проанализируем окупаемость рекламы с разбивкой по устройствам;
# - Проанализируем окупаемость рекламы с разбивкой по странам;
# - Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.

# %% [markdown]
# ### Общая окупаемость рекламы

# %% [markdown]
# Исключим профили органических пользователей для дальнейшего анализа. Так же выделим отдельно пользователей из США и Европы.

# %%
profiles = profiles.query('channel!="organic"')
usa_profiles = profiles.query('region_type=="USA"')
eu_profiles = profiles.query('region_type=="EU"')

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, analysis_horizon
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon)

# %% [markdown]
# По графикам можно сделать следующие выводы:
# - Реклама не окупается, к концу второй недели ROI - 80%
# - CAC растет с каждым месяцем.
# - LTV достаточно стабилен, значит качество пользователей стабильно.
# - Окупаемость рекламы снижается, а затраты на привлечение новых пользователей растут.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, analysis_horizon, dimensions=dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon)

# %% [markdown]
# По графикам в разбивке по устройствам можно сделать следующие выводы:
# - Реклама окупается для пользователей PC.
# - CAC для пользователей iPhone и Mac выше. При этом графики динамики CAC очень схожи, возможно, что затраты высоки в определенной стране и распределены по разным девайсам.
# - Окупаемость снижается для всех устройств при этом затраты на привлечение новых вользователей растут.
# - LTV стабилен для всех устройств.

# %% [markdown]
# Поанализируем конверсию и удержание в разбивке по устройствам.

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles,
    orders,
    observation_date,
    analysis_horizon,
    dimensions=dimensions
)

plot_conversion(conversion, conversion_history, analysis_horizon)

# %% [markdown]
# - Пользователи iPhone и Mac конвертируются лучше всего.

# %%
retention_raw, retention, retention_history = get_retention(
    profiles,
    visits,
    observation_date,
    analysis_horizon,
    dimensions=dimensions
)

plot_retention(retention, retention_history, analysis_horizon)

# %% [markdown]
# - Пользователи PС показывают самую низкую конверсию из всех устройств, однако они лучше всех удерживаются.
# - Лидеры по конверсии iPhone и Mac удерживаются хуже.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, analysis_horizon, dimensions=dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon)

# %% [markdown]
# По графикам в разбивке по странам можно сделать следующие выводы:
# - Реклама окупается для стран Европы, к концу второй недели ROI около 150%. А вот США не окупается, к концу второй недели ROI около 70%.
# - CAC стабилен для стран Европы, с июня затраты даже снизились и держатся на одном уровне. Для США CAC растет начиная с июня 2019 года, где претерпевает значительный скачок.
# - LTV стабилен для всех стран. При этом пользователи из США "ценнее" пользователей из стран Европы.
# - Окупаемость рекламы падает только для США, при этом затраты на привлечение новых пользователей растут.

# %% [markdown]
# Поанализируем конверсию и удержание в разбивке по странам.

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles,
    orders,
    observation_date,
    analysis_horizon,
    dimensions=dimensions
)

plot_conversion(conversion, conversion_history, analysis_horizon)

# %% [markdown]
# - Конверсия пользователей из США в 2 раза выше конверсии пользователей из стран Европы.

# %%
retention_raw, retention, retention_history = get_retention(
    profiles,
    visits,
    observation_date,
    analysis_horizon,
    dimensions=dimensions
)

plot_retention(retention, retention_history, analysis_horizon)

# %% [markdown]
# - Пользователи из США хуже удерживаются, чем пользователи из Европы.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Поскольку мы выяснили, что в США и Европе используются разные каналы привелечения, то отдельно рассмотрим США и Европу.

# %% [markdown]
# Сначала рассмотрим пользователей из США

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    usa_profiles, orders, observation_date, analysis_horizon, dimensions=dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon)

# %% [markdown]
# По графикам можно сделать следующие выводы:
# - Реклама не окупается для каналов привлечения FaceBoom и TipTop.
# - CAC стабилен для всех каналов, кроме TipTop - здесь с каждым месяцем затраты на привлечение увеличиваются.
# - LTV стабилен для всех каналов. При этом наиболее "ценными" являются пользователи из каналов TipTop, RocketSuperAds, FaceBoom.

# %% [markdown]
# Поанализируем конверсию и удержание.

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    usa_profiles,
    orders,
    observation_date,
    analysis_horizon,
    dimensions=dimensions
)

plot_conversion(conversion, conversion_history, analysis_horizon)

# %% [markdown]
# - Пользователи из каналов TipTop, RocketSuperAds, FaceBoom так же и лучше конвертируются.

# %%
retention_raw, retention, retention_history = get_retention(
    usa_profiles,
    visits,
    observation_date,
    analysis_horizon,
    dimensions=dimensions
)

plot_retention(retention, retention_history, analysis_horizon)

# %% [markdown]
# - Вот с удержанием пользователей из FaceBoom все очень плохо. Возможно причиной является технический сбой при переходе из FaceBoom в наше приложение.

# %% [markdown]
# ***

# %% [markdown]
# Рассмотрим теперь страны Европы.

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    eu_profiles, 
    orders, observation_date, analysis_horizon, dimensions=dimensions
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon)

# %% [markdown]
# - Реклама не окупается для канала AdNonSence.
# - CAC сохраняется на одном уровне для каждого канала.
# - LTV стабилен. Наиболее ценными являются пользователи из канала lambdaMediaAds.

# %% [markdown]
# Поанализируем конверсию и удержание.

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    eu_profiles,
    orders,
    observation_date,
    analysis_horizon,
    dimensions=dimensions
)

plot_conversion(conversion, conversion_history, analysis_horizon)

# %% [markdown]
# - Лучше всего конвертируются пользователи из AdNonSense и lambdaMediaAds

# %%
retention_raw, retention, retention_history = get_retention(
    eu_profiles,
    visits,
    observation_date,
    analysis_horizon,
    dimensions=dimensions
)

plot_retention(retention, retention_history, analysis_horizon)

# %% [markdown]
# - С удержанием у AdNonSense плохо. Возможно так же, что происходит техническая неполадка при переходе из этого канала в наше приложение.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. **В общем** реклама не окупается. ROI падает, при этом растут затраты на привлечение пользователей.
#
#
# 2. **В разбивке по девайсам**:
#     - Реклама окупается для пользователей PC, скорее всего потому что затраты на привлечение наименьшие.
#     - CAC для пользователей iPhone и Mac также выше.
#     - Окупаемость снижается для всех устройств при этом затраты на привлечение новых вользователей растут.
#     - Пользователи PС показывают самую низкую конверсию из всех устройств, однако они лучше всех удерживаются.
#     - Лидеры по конверсии iPhone и Mac удерживаются хуже.
#
#
# 3. **В разбивке по странам**:
#     - Реклама окупается для стран Европы, для США нет.
#     - CAC стабилен для стран Европы, для США CAC растет начиная с июня 2019 года, где претерпевает значительный скачок.
#     - LTV стабилен для всех стран. При этом пользователи из США "ценнее" пользователей из стран Европы.
#     - Окупаемость рекламы падает только для США, при этом затраты на привлечение новых пользователей растут.
#     - Конверсия пользователей из США в 2 раза выше конверсии пользователей из стран Европы.
#     - Пользователи из США хуже удерживаются, чем пользователи из Европы.
#
#
# 4. **В разбивке по каналам привлечения**:
#
#     **Для США**:
#     - Реклама не окупается для каналов привлечения FaceBoom и TipTop.
#     - CAC стабилен для всех каналов, кроме TipTop - здесь с каждым месяцем затраты на привлечение увеличиваются.
#     - LTV стабилен для всех каналов. При этом наиболее "ценными" являются пользователи из каналов TipTop, RocketSuperAds, FaceBoom.
#     - Пользователи из каналов TipTop, RocketSuperAds, FaceBoom так же и лучше конвертируются.
#     - C удержанием пользователей из FaceBoom плохо. Возможно причиной является технический сбой при переходе из FaceBoom в наше приложение.
#
#    **Для Европы**:
#     - Реклама окупается для всех каналов, кроме AdNonSence.
#     - CAC сохраняется на одном уровне для каждого канала.
#     - LTV стабилен. Наиболее ценными являются пользователи из канала lambdaMediaAds.
#     - Лучше всего конвертируются пользователи из AdNonSense и lambdaMediaAds.
#     - С удержанием у AdNonSense плохо. Возможно так же, что происходит техническая неполадка при переходе из этого канала в наше приложение.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Причины неэффективности**:
# - Очень большая ставка на США.
# - В США преобладают пользователи `iPhone` и `Mac` - их привлечение достаточно дорого обходится
# - В США преобладают пользователи привлеченные из `FaceBoom` и `TipTop` - очень популярные и посещаемые платформы.
# - `TipTop` - конверсия (9.6%) и удержание пользователей высокие, однако затраты на рекламу очень высоки (51.9%) и реклама не окупается.
# - `FaceBoom` - конверсия (12.2%) высока и больше всего пользователей привлекается оттуда. Однако удержание низкое - возможная причина техническая неполадка, нужно разобраться.
#
#
# - Из стран Европы привлекается в два раза меньше пользователей чем из США.
# - Возможно вкладываются деньги не в те каналы привлечения: `OppleCreativeMedia`(конверсия 2.71%), `LeapBob` (конверсия 3.06%)
# - Канал `AdNonSense` - высокий LTV, стабильные затраты на привлечение, высокая конверсия (11.34%), но при этом самое низкое удержание - возможно технический сбой.

# %% [markdown]
# **Рекомендации**
# - В США стоит обратить внимание на `RocketSuperAds` у него высокий LTV и ROI и конверсия (7.91%), затраты на привлечение стабильны, так же разобраться с неполадками в `FaceBoom`, пересмотреть ценовую политику в привлечении пользователей из `TipTop`.
#
#
# - Стоит обратить внимание на привлечение пользователей из Европы.
# - В Европе преобладают пользователи PC и Android - их привлечение стоит дешевле.
# - В Европе стоит обратить внимание на канал `lambdaMediaAds` - высокая конверсия (10.47%), при этом затраты на привлечение стабильны, так же стоит устранить причину низкого удержания в канале `AdNonSense`
